# %%
import os
os.chdir('..')

# %%
import torch
import pickle
import numpy as np

from gnn_library.util import load
from evaluate import evaluate_model
from instance_generator import sample_instances
from params import *
from util import _plot_approx_ratios_all

# %load_ext autoreload
# %autoreload 2

# %%
device = torch.device('cuda:5' if torch.cuda.is_available() else 'cpu')
print("PyTorch has version {}".format(torch.__version__))
print('Using device:', device)

GNN, args = load('GNN_exp_diff_7_4', device)
# Out:
# PyTorch has version 1.12.0+cu102
# Using device: cuda:5

# %% [markdown]
# ## Size generalization experiment

# %% [markdown]
# #### Evaluate CRs for all graph configurations across different graph sizes

# %%
from params import EXPERIMENT_SIZE_GENERALIZATION_REGIMES

rng = np.random.default_rng(seed=0)
# num_trials = 150
num_trials = 30
batch_size = 500
# graph_configs = ALL_TESTING_GRAPH_CONFIGS
graph_configs = MAIN_TESTING_GRAPH_CONFIGS

node_configs = EXPERIMENT_SIZE_GENERALIZATION_REGIMES
sizes = [x+y for (x,y) in node_configs]
baselines_kwargs = {
    'greedy': {},
    'greedy_t': {'threshold': 0.35},
    'lp_rounding': {},
    'naor_lp_rounding': {}
}

data = [[] for _ in range(len(graph_configs))]

##### REMOVE #####
# graph_configs = MAIN_TESTING_GRAPH_CONFIGS[2:]

# with open(f"experiments/transferability_gnn2.pickle", 'rb') as handle:
#     data = pickle.load(handle)
#####  END   #####



for data_index, graph_config in enumerate(graph_configs):
    for i, node_config in enumerate(node_configs):
        print(node_config, graph_config)
        
        instances = sample_instances(
            *node_config,
            num_trials,
            rng,
            args.__dict__,
            **graph_config
        )

        cr_ratios, _ = evaluate_model(
            meta_model=None,
            meta_model_type=None,
            base_models=[GNN],
            instances=instances,
            batch_size=batch_size,
            rng=rng,
            num_realizations=5,
            # baselines=['greedy', 'greedy_t', 'lp_rounding', 'naor_lp_rounding'],
            baselines=[],
            **baselines_kwargs
        )

        data[data_index].append(cr_ratios)
    

        with open(f"experiments/transferability_gnn2_6.pickle", 'wb') as handle:
            pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)
        with torch.no_grad():
            torch.cuda.empty_cache()
# Out:
# (20, 10) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.9094164678826928
# GNN time: 7.847720834426582
# Baseline times: {}
# (28, 14) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.6159705738537014
# GNN time: 10.822758314665407
# Baseline times: {}
# (36, 18) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.5023211911320686
# GNN time: 13.96316771581769
# Baseline times: {}
# (44, 22) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.5906954230740666
# GNN time: 17.625795926898718
# Baseline times: {}
# (52, 26) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.9843439906835556
# GNN time: 27.026980059221387
# Baseline times: {}
# (60, 30) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 1.0282248947769403
# GNN time: 32.178605671972036
# Baseline times: {}
# (68, 34) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 1.0378815168514848
# GNN time: 28.14317354373634
# Baseline times: {}
# (76, 38) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 1.2407417288050056
# GNN time: 32.07718897983432
# Baseline times: {}
# (20, 10) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.4253230281174183
# GNN time: 8.372003647033125
# Baseline times: {}
# (28, 14) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.4315945217385888
# GNN time: 10.915248136036098
# Baseline times: {}
# (36, 18) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.5704705100506544
# GNN time: 18.394583475776017
# Baseline times: {}
# (44, 22) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.5518880351446569
# GNN time: 18.474543627351522
# Baseline times: {}
# (52, 26) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.554783949162811
# GNN time: 22.17643208289519
# Baseline times: {}
# (60, 30) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.6428361367434263
# GNN time: 25.40557915531099
# Baseline times: {}
# (68, 34) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.9184802966192365
# GNN time: 34.950029086787254
# Baseline times: {}
# (76, 38) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.9073940310627222
# GNN time: 32.28881237609312
# Baseline times: {}
# (20, 10) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.4683341346681118
# GNN time: 8.04483788087964
# Baseline times: {}
# (28, 14) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.6209994121454656
# GNN time: 14.276525248773396
# Baseline times: {}
# (36, 18) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.9154824982397258
# GNN time: 18.542507744859904
# Baseline times: {}
# (44, 22) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 1.03480977518484
# GNN time: 22.74962045904249
# Baseline times: {}
# (52, 26) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 1.318516616243869
# GNN time: 26.945172713138163
# Baseline times: {}
# (60, 30) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 1.7441492350772023
# GNN time: 31.281744884792715
# Baseline times: {}
# (68, 34) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 2.207870496902615
# GNN time: 29.430980337318033
# Baseline times: {}
# (76, 38) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 2.84307300997898
# GNN time: 39.97262469306588
# Baseline times: {}
# (20, 10) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.4222443918697536
# GNN time: 8.13054275792092
# Baseline times: {}
# (28, 14) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.40252774115651846
# GNN time: 10.686336531303823
# Baseline times: {}
# (36, 18) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.4215986030176282
# GNN time: 13.894878418184817
# Baseline times: {}
# (44, 22) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.5715724457986653
# GNN time: 22.79455931810662
# Baseline times: {}
# (52, 26) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.465921682305634
# GNN time: 20.38139689899981
# Baseline times: {}
# (60, 30) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.7964474009349942
# GNN time: 31.078124921768904
# Baseline times: {}
# (68, 34) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.6380726848728955
# GNN time: 35.353301589842886
# Baseline times: {}
# (76, 38) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.8903976022265851
# GNN time: 39.315593709237874
# Baseline times: {}

# %% [markdown]
# #### Generate size generalization plots

# %%
from util import _plot_approx_ratios

with open(f"experiments/transferability_gnn2_6.pickle", 'rb') as handle:
    results = pickle.load(handle)

filtered_results = {frozenset(g.items()): data for g, data in zip(graph_configs, results)}
_plot_approx_ratios(sizes, filtered_results, x_axis_name= "Total number of nodes $N$", confidence = 0.95)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/alexhay/GNN-OBM/notebooks/exp_size_generalization copy 4.ipynb Cell 8 in <cell line: 7>()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22736f616c2d372e7374616e666f72642e656475222c2275736572223a22616c6578686179227d/home/alexhay/GNN-OBM/notebooks/exp_size_generalization%20copy%204.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     results = pickle.load(handle)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22736f616c2d372e7374616e666f72642e656475222c2275736572223a22616c6578686179227d/home/alexhay/GNN-OBM/notebooks/exp_size_generalization%20copy%204.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> filtered_results = {frozenset(g.items()): data for g, data in zip(graph_configs, results)}
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22736f616c2d372e7374616e666f72642e656475222c2275736572223a22616c6578686179227d/home/alexhay/GNN-OBM/notebooks/exp_size_generalization%20copy%204.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> _plot_approx_ratios(sizes, filtered_results, x_axis_name= "Total number of nodes $N$", confidence = 0.95)
#
# File ~/GNN-OBM/util.py:260, in _plot_approx_ratios(ratios, data, naming_function, x_axis_name, confidence)
#     256     i += 1
#     258 order = [0, 1, 3, 2]
#     259 fig.legend(
# --> 260     [handles[idx] for idx in order],
#     261     [labels[idx] for idx in order],
#     262     bbox_to_anchor=(1.08, 0.25),
#     263     loc='lower right',
#     264     fontsize=15
#     265 )
#     266 plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
#     267 plt.xlabel(x_axis_name, fontsize = fontsize2 - 2, labelpad=15)
#
# File ~/GNN-OBM/util.py:260, in <listcomp>(.0)
#     256     i += 1
#     258 order = [0, 1, 3, 2]
#     259 fig.legend(
# --> 260     [handles[idx] for idx in order],
#     261     [labels[idx] for idx in order],
#     262     bbox_to_anchor=(1.08, 0.25),
#     263     loc='lower right',
#     264     fontsize=15
#     265 )
#     266 plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
#     267 plt.xlabel(x_axis_name, fontsize = fontsize2 - 2, labelpad=15)
#
# IndexError: list index out of range
