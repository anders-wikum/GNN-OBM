# %%
import os
os.chdir('..')

# %%
import torch
import pickle
import numpy as np

from gnn_library.util import load
from evaluate import evaluate_model
from instance_generator import sample_instances
from params import *
from util import _plot_approx_ratios_all

# %load_ext autoreload
# %autoreload 2

# %%
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')
print("PyTorch has version {}".format(torch.__version__))
print('Using device:', device)

GNN, args = load('GNN_exp_diff_30_14', device)
# Out:
# PyTorch has version 1.12.0+cu102
# Using device: cuda:3

# %% [markdown]
# ## Size generalization experiment

# %% [markdown]
# #### Evaluate CRs for all graph configurations across different graph sizes

# %%
from params import EXPERIMENT_SIZE_GENERALIZATION_REGIMES

rng = np.random.default_rng(seed=0)
# num_trials = 150
num_trials = 30
batch_size = 500
# graph_configs = ALL_TESTING_GRAPH_CONFIGS
graph_configs = MAIN_TESTING_GRAPH_CONFIGS

node_configs = EXPERIMENT_SIZE_GENERALIZATION_REGIMES
sizes = [x+y for (x,y) in node_configs]
baselines_kwargs = {
    'greedy': {},
    'greedy_t': {'threshold': 0.35},
    'lp_rounding': {},
    'naor_lp_rounding': {}
}

data = [[] for _ in range(len(graph_configs))]

##### REMOVE #####
# graph_configs = MAIN_TESTING_GRAPH_CONFIGS[2:]

# with open(f"experiments/transferability_gnn2.pickle", 'rb') as handle:
#     data = pickle.load(handle)
#####  END   #####



for data_index, graph_config in enumerate(graph_configs):
    for i, node_config in enumerate(node_configs):
        print(node_config, graph_config)
        
        instances = sample_instances(
            *node_config,
            num_trials,
            rng,
            args.__dict__,
            **graph_config
        )

        cr_ratios, _ = evaluate_model(
            meta_model=None,
            meta_model_type=None,
            base_models=[GNN],
            instances=instances,
            batch_size=batch_size,
            rng=rng,
            num_realizations=5,
            # baselines=['greedy', 'greedy_t', 'lp_rounding', 'naor_lp_rounding'],
            baselines=[],
            **baselines_kwargs
        )

        data[data_index].append(cr_ratios)
    

        with open(f"experiments/transferability_gnn2_8.pickle", 'wb') as handle:
            pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)
        with torch.no_grad():
            torch.cuda.empty_cache()
# Out:
# (20, 10) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.9168100440874696
# GNN time: 8.017317027784884
# Baseline times: {}
# (28, 14) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.44458046928048134
# GNN time: 10.696534889750183
# Baseline times: {}
# (36, 18) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.7285811868496239
# GNN time: 18.419953810982406
# Baseline times: {}
# (44, 22) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.6793662081472576
# GNN time: 22.64682337315753
# Baseline times: {}
# (52, 26) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.7407852620817721
# GNN time: 22.27342631109059
# Baseline times: {}
# (60, 30) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 1.0388539959676564
# GNN time: 30.946817042771727
# Baseline times: {}
# (68, 34) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 1.039836322888732
# GNN time: 27.134003959130496
# Baseline times: {}
# (76, 38) {'graph_type': 'ER', 'p': 0.5, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 1.154326168820262
# GNN time: 30.68684554612264
# Baseline times: {}
# (20, 10) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.5217718542553484
# GNN time: 9.874708948191255
# Baseline times: {}
# (28, 14) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.5302044316194952
# GNN time: 13.94991696998477
# Baseline times: {}
# (36, 18) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.5611811741255224
# GNN time: 13.86147889494896
# Baseline times: {}
# (44, 22) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.47918929997831583
# GNN time: 17.125291421078146
# Baseline times: {}
# (52, 26) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.6420229622162879
# GNN time: 20.31602475605905
# Baseline times: {}
# (60, 30) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.6761907297186553
# GNN time: 23.60071267792955
# Baseline times: {}
# (68, 34) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.8524662470445037
# GNN time: 35.047018677927554
# Baseline times: {}
# (76, 38) {'graph_type': 'GEOM', 'q': 0.25, 'd': 2, 'weighted': True}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.8889725729823112
# GNN time: 39.57986769080162
# Baseline times: {}
# (20, 10) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.5150376399978995
# GNN time: 8.240526298992336
# Baseline times: {}
# (28, 14) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.7715119933709502
# GNN time: 14.350082150194794
# Baseline times: {}
# (36, 18) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.7063543600961566
# GNN time: 18.448777239304036
# Baseline times: {}
# (44, 22) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 1.0299861668609083
# GNN time: 18.20033046696335
# Baseline times: {}
# (52, 26) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 1.3548836642876267
# GNN time: 26.283003595191985
# Baseline times: {}
# (60, 30) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 1.6978683932684362
# GNN time: 31.199217750690877
# Baseline times: {}
# (68, 34) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 2.1506417407654226
# GNN time: 29.347618115134537
# Baseline times: {}
# (76, 38) {'graph_type': 'OSMNX', 'location': 'Fremont, California, USA'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 2.3944455650635064
# GNN time: 33.05066565377638
# Baseline times: {}
# (20, 10) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.38811218133196235
# GNN time: 7.477177741937339
# Baseline times: {}
# (28, 14) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.40013368567451835
# GNN time: 10.609068808145821
# Baseline times: {}
# (36, 18) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.5304663483984768
# GNN time: 18.35982923442498
# Baseline times: {}
# (44, 22) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.4738577720709145
# GNN time: 18.66049508191645
# Baseline times: {}
# (52, 26) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.48246155166998506
# GNN time: 21.44292950630188
# Baseline times: {}
# (60, 30) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.4928418016061187
# GNN time: 23.793688119854778
# Baseline times: {}
# (68, 34) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.6165656819939613
# GNN time: 27.150752066168934
# Baseline times: {}
# (76, 38) {'graph_type': 'GM'}
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Set parameter TokenServer to value "soal-nas.stanford.edu"
# Generation time: 0.6699105380102992
# GNN time: 31.156283599324524
# Baseline times: {}

# %% [markdown]
# #### Generate size generalization plots

# %%
from util import _plot_approx_ratios

with open(f"experiments/transferability_gnn2_8.pickle", 'rb') as handle:
    results = pickle.load(handle)

filtered_results = {frozenset(g.items()): data for g, data in zip(graph_configs, results)}
_plot_approx_ratios(sizes, filtered_results, x_axis_name= "Total number of nodes $N$", confidence = 0.95)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/alexhay/GNN-OBM/notebooks/exp_size_generalization copy 3.ipynb Cell 8 in <cell line: 7>()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22736f616c2d372e7374616e666f72642e656475222c2275736572223a22616c6578686179227d/home/alexhay/GNN-OBM/notebooks/exp_size_generalization%20copy%203.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     results = pickle.load(handle)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22736f616c2d372e7374616e666f72642e656475222c2275736572223a22616c6578686179227d/home/alexhay/GNN-OBM/notebooks/exp_size_generalization%20copy%203.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> filtered_results = {frozenset(g.items()): data for g, data in zip(graph_configs, results)}
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22736f616c2d372e7374616e666f72642e656475222c2275736572223a22616c6578686179227d/home/alexhay/GNN-OBM/notebooks/exp_size_generalization%20copy%203.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> _plot_approx_ratios(sizes, filtered_results, x_axis_name= "Total number of nodes $N$", confidence = 0.95)
#
# File ~/GNN-OBM/util.py:260, in _plot_approx_ratios(ratios, data, naming_function, x_axis_name, confidence)
#     256     i += 1
#     258 order = [0, 1, 3, 2]
#     259 fig.legend(
# --> 260     [handles[idx] for idx in order],
#     261     [labels[idx] for idx in order],
#     262     bbox_to_anchor=(1.08, 0.25),
#     263     loc='lower right',
#     264     fontsize=15
#     265 )
#     266 plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
#     267 plt.xlabel(x_axis_name, fontsize = fontsize2 - 2, labelpad=15)
#
# File ~/GNN-OBM/util.py:260, in <listcomp>(.0)
#     256     i += 1
#     258 order = [0, 1, 3, 2]
#     259 fig.legend(
# --> 260     [handles[idx] for idx in order],
#     261     [labels[idx] for idx in order],
#     262     bbox_to_anchor=(1.08, 0.25),
#     263     loc='lower right',
#     264     fontsize=15
#     265 )
#     266 plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
#     267 plt.xlabel(x_axis_name, fontsize = fontsize2 - 2, labelpad=15)
#
# IndexError: list index out of range
